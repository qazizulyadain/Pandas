# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('../lecture7/movies.csv')

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# using lists
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

column_name = ['iq','marks','package']
df = pd.DataFrame(student_data, columns=column_name, index=['Ahmad', 'Hassan', 'Muhammad', 'Hamza'])

# %%
df
# Out:
#            iq  marks  package
# Ahmad     100     80       10
# Hassan     90     70        7
# Muhammad  120    100       14
# Hamza      80     50        2

# %% [markdown]
# ## **Selecting cols from DataFrame**

# %%
# single cols
df['marks']
# Out:
# Ahmad        80
# Hassan       70
# Muhammad    100
# Hamza        50
# Name: marks, dtype: int64

# %%
# multiple cols
df[['iq', 'marks']]
# Out:
#            iq  marks
# Ahmad     100     80
# Hassan     90     70
# Muhammad  120    100
# Hamza      80     50

# %% [markdown]
# ## **Selecting rows from a DataFrame**
#
# - **iloc** - searches using index positions
# - **loc** - searches using index labels

# %%
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies.iloc[10].poster_path
# Out:
# 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b3/Amavas_official_poster.jpg/220px-Amavas_official_poster.jpg'

# %%
type(movies.iloc[0])
# Out:
# pandas.core.series.Series

# %%
movies.shape
# Out:
# (1629, 18)

# %%
# single row
movies.iloc[0:10:2, 0:18:2]
# Out:
#                                 title_x  \
# 0              Uri: The Surgical Strike
# 2  The Accidental Prime Minister (film)
# 4                       Evening Shadows
# 6                         Fraud Saiyaan
# 8      Manikarnika: The Queen of Jhansi
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
# 8  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                             title_y  is_adult runtime  imdb_rating  \
# 0          Uri: The Surgical Strike         0     138          8.4
# 2     The Accidental Prime Minister         0     112          6.1
# 4                   Evening Shadows         0     102          7.3
# 6                     Fraud Saiyaan         0     109          4.2
# ...

# %%
# multiple row

# %%
df
# Out:
#            iq  marks  package
# Ahmad     100     80       10
# Hassan     90     70        7
# Muhammad  120    100       14
# Hamza      80     50        2

# %%
df.iloc[0:3]
# Out:
#            iq  marks  package
# Ahmad     100     80       10
# Hassan     90     70        7
# Muhammad  120    100       14

# %%
# fancy indexing
movies.iloc[[0, 2, 4, 6, 8], [0, 3, 6]]
# Out:
#                                 title_x  \
# 0              Uri: The Surgical Strike
# 2  The Accidental Prime Minister (film)
# 4                       Evening Shadows
# 6                         Fraud Saiyaan
# 8      Manikarnika: The Queen of Jhansi
#
#                                            wiki_link  is_adult
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...         0
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...         0
# 4      https://en.wikipedia.org/wiki/Evening_Shadows         0
# 6        https://en.wikipedia.org/wiki/Fraud_Saiyaan         0
# 8  https://en.wikipedia.org/wiki/Manikarnika:_The...         0

# %%
df
# Out:
#            iq  marks  package
# Ahmad     100     80       10
# Hassan     90     70        7
# Muhammad  120    100       14
# Hamza      80     50        2

# %%
# loc
df.loc['Ahmad': 'Muhammad']
# Out:
#            iq  marks  package
# Ahmad     100     80       10
# Hassan     90     70        7
# Muhammad  120    100       14

# %%
movies.loc[0:5, 'title_x':	'wiki_link']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# ...

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %% [markdown]
# ## **Selecting both rows and cols**

# %%
# iloc

# %%
# loc

# %% [markdown]
# ## **Filtering a DataFrame**

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies["imdb_rating"] > 8.0
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628     True
# Name: imdb_rating, Length: 1629, dtype: bool

# %%
# movies with rating higher than 8 and votes>10000
rating = movies["imdb_rating"] > 8.0
votes = movies['imdb_votes'] > 10000

# %%
len(movies[rating & votes])
# Out:
# 43

# %%
movies[(movies["imdb_rating"] > 8.0) & (movies['imdb_votes'] > 10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies['genres']
# Out:
# 0       Action|Drama|War
# 1                    War
# 2        Biography|Drama
# 3            Crime|Drama
# 4                  Drama
#               ...
# 1624               Drama
# 1625               Drama
# 1626        Comedy|Drama
# 1627              Action
# 1628       Drama|Romance
# Name: genres, Length: 1629, dtype: object

# %%
movies['genres'].apply(lambda x :x.split('|'))
# Out:
# 0       [Action, Drama, War]
# 1                      [War]
# 2         [Biography, Drama]
# 3             [Crime, Drama]
# 4                    [Drama]
#                 ...
# 1624                 [Drama]
# 1625                 [Drama]
# 1626         [Comedy, Drama]
# 1627                [Action]
# 1628        [Drama, Romance]
# Name: genres, Length: 1629, dtype: object

# %%
movies['genres3'] = movies['genres'].apply(lambda x :x.split('|'))

# %%
# Action movies with rating higher than 7.5
movies[(movies['genres'] == 'Action') & (movies['imdb_rating'] > 7.5)]
# Out:
# Empty DataFrame
# Columns: [title_x, imdb_id, poster_path, wiki_link, title_y, original_title, is_adult, year_of_release, runtime, genres, imdb_rating, imdb_votes, story, summary, tagline, actors, wins_nominations, release_date, genres3]
# Index: []

# %% [markdown]
# ## **Adding new cols**

# %%
movies['COuntry'] = 'India'

# %%
movies.sample(3)
# Out:
#                              title_x    imdb_id  \
# 1193  Mere Jeevan Saathi (2006 film)  tt0418880
# 49                   The Sky Is Pink  tt8902990
# 655                War Chhod Na Yaar  tt3129282
#
#                                             poster_path  \
# 1193  https://upload.wikimedia.org/wikipedia/en/thum...
# 49    https://upload.wikimedia.org/wikipedia/en/thum...
# 655   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link             title_y  \
# 1193  https://en.wikipedia.org/wiki/Mere_Jeevan_Saat...  Mere Jeevan Saathi
# 49        https://en.wikipedia.org/wiki/The_Sky_Is_Pink     The Sky Is Pink
# 655     https://en.wikipedia.org/wiki/War_Chhod_Na_Yaar    War Chod Na Yaar
#
#           original_title  is_adult  year_of_release runtime  \
# 1193  Mere Jeevan Saathi         0             2006     129
# 49       The Sky Is Pink         0             2019     143
# ...
