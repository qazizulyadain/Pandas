# %%
import pandas as pd

# %%
data = pd.read_csv('./subs.csv')
data = data.squeeze()

# %%
movies = pd.read_csv('./bollywood.csv', index_col='movie')
movies = movies.squeeze()

# %% [markdown]
# ## **Boolean Indexing on Series**

# %%
data.size
# Out:
# 365

# %%
data
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
data[data > 300].size
# Out:
# 4

# %%
data
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
data[data < 50].size
# Out:
# 23

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
# find actors who have done more than 20 movies
num_moveies = movies.value_counts()

# %%
num_moveies
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
num_moveies[num_moveies >= 30]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Name: count, dtype: int64

# %% [markdown]
# ## **Plotting Graphs on Series**

# %%
data.max()
# Out:
# np.int64(396)

# %%
data.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(5).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## **Some Important Series Methods**

# %%
data
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# between
data[data.between(50, 100)]
# Out:
# 1      57
# 9      74
# 11     56
# 16     54
# 17     51
#        ..
# 180    93
# 184    76
# 209    91
# 210    97
# 211    98
# Name: Subscribers gained, Length: 102, dtype: int64

# %%
# clip
